# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import csv
import janitor
import numpy as np

# %%
# reading in mapping file
mapping = pd.read_csv("~/Documents/thesis/paper-mapping/16Sprocessed_CollectionRep1.csv")

# %%
mapping
# Out:
#         SampleID Mother_Child  SubjectID MaternalID  TimePoint Fecal_EtOH  \
# 0    C0052_5F_1A            C         52     0052_m          5          F
# 1    C0126_8F_1A            C        126     0126_m          8          F
# 2    C0126_8F_1B            C        126     0126_m          8          F
# 3    C0127_6F_1B            C        127     0127_m          6          F
# 4    C0286_5F_1A            C        286     0286_m          5          F
# 5    C0296_5F_1A            C        296     0296_m          5          F
# 6    C0053_6F_1A            C         53     0053_m          6          F
# 7    C0108_4F_1A            C        108     0108_m          4          F
# 8    C0498_1F_1A            C        498     0498_m          1          F
# 9    C0043_7F_1A            C         43     0043_m          7          F
# 10   C0117_4F_1A            C        117     0117_m          4          F
# 11   C0117_4F_1B            C        117     0117_m          4          F
# ...

# %%
mapping.rename(columns={"SampleID": "#SampleID"}, inplace=True)

# %%
mapping['#SampleID'] = mapping['#SampleID'].str.replace('_','-')

# %%
mapping
# Out:
#        #SampleID Mother_Child  SubjectID MaternalID  TimePoint Fecal_EtOH  \
# 0    C0052-5F-1A            C         52     0052_m          5          F
# 1    C0126-8F-1A            C        126     0126_m          8          F
# 2    C0126-8F-1B            C        126     0126_m          8          F
# 3    C0127-6F-1B            C        127     0127_m          6          F
# 4    C0286-5F-1A            C        286     0286_m          5          F
# 5    C0296-5F-1A            C        296     0296_m          5          F
# 6    C0053-6F-1A            C         53     0053_m          6          F
# 7    C0108-4F-1A            C        108     0108_m          4          F
# 8    C0498-1F-1A            C        498     0498_m          1          F
# 9    C0043-7F-1A            C         43     0043_m          7          F
# 10   C0117-4F-1A            C        117     0117_m          4          F
# 11   C0117-4F-1B            C        117     0117_m          4          F
# ...

# %%
with open("cross-sec-samples.txt", "r") as f:
    fastq=[i for line in f for i in line.split(',')]

# %%
fastq = [s.replace('\n', '') for s in fastq]

# %%
mapping = mapping[mapping['#SampleID'].isin(fastq)]

# %%
# remove empty columns
mapping.dropna(how='all', axis=1, inplace=True)
# fill NaN

mapping = mapping.fillna('NaN')
# Out:
# /Users/danielle/miniconda2/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mapping
# Out:
#        #SampleID Mother_Child  SubjectID MaternalID  TimePoint Fecal_EtOH  \
# 0    C0660-1E-1A            C        660     0660_m          1          E
# 1    C0683-1E-1A            C        683     0683_m          1          E
# 2    C0686-1E-1A            C        686     0686_m          1          E
# 3    C0107-4E-1A            C        107     0107_m          4          E
# 4    C0106-6E-1A            C        106     0106_m          6          E
# 5    C0673-1E-1A            C        673     0673_m          1          E
# 6    C0202-6E-1A            C        202     0202_m          6          E
# 7    C0679-1E-1A            C        679     0679_m          1          E
# 8    C0688-1E-1A            C        688     0688_m          1          E
# 9    C0237-4E-1A            C        237     0237_m          4          E
# 10   C0694-1E-1A            C        694     0694_m          1          E
# 11   C0123-3E-1A            C        123     0123_m          3          E
# ...

# %%
mapping.to_csv('paper-qiime2-mapping.csv', index=False)
