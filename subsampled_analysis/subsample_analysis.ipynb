# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import csv
import janitor
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
subsample = pd.read_csv("~/Documents/thesis/subsampled_analysis/merged_abundance_table.tsv", sep='\t')

# %%
# only keep genera
subsample = subsample[subsample['ID'].str.contains("\|s__")]
subsample = subsample[~subsample['ID'].str.contains("\|t__")]

# %%
subsample["ID"] = subsample['ID'].str.split("\|g__").str[-1]
subsample["ID"] = subsample['ID'].str.split("\|s__").str[0]

# %%
subsample.head()
# Out:
#                     ID  C0005_3F_1A_1000k_1_profile  \
# 6   Methanobrevibacter                      0.00000
# 8   Methanobrevibacter                      0.00000
# 15         Actinomyces                      0.00000
# 18         Varibaculum                      0.00000
# 23     Bifidobacterium                      0.37811
#
#     C0005_3F_1A_1000k_2_profile  C0005_3F_1A_1000k_3_profile  \
# 6                       0.00000                      0.00000
# 8                       0.00000                      0.00000
# 15                      0.00000                      0.00000
# 18                      0.00000                      0.00000
# 23                      0.41119                      0.39722
#
#     C0005_3F_1A_1000k_4_profile  C0005_3F_1A_100k_1_profile  \
# 6                       0.00000                         0.0
# 8                       0.00000                         0.0
# 15                      0.00000                         0.0
# 18                      0.00000                         0.0
# 23                      0.37526                         0.0
#
#     C0005_3F_1A_100k_2_profile  C0005_3F_1A_100k_3_profile  \
# 6                          0.0                         0.0
# 8                          0.0                         0.0
# 15                         0.0                         0.0
# 18                         0.0                         0.0
# 23                         0.0                         0.0
#
#     C0005_3F_1A_100k_4_profile  C0005_3F_1A_10k_1_profile  ...  \
# 6                          0.0                        0.0  ...
# 8                          0.0                        0.0  ...
# 15                         0.0                        0.0  ...
# 18                         0.0                        0.0  ...
# 23                         0.0                        0.0  ...
#
#     C0785_1F_1A_1000k_3_profile  C0785_1F_1A_1000k_4_profile  \
# 6                       0.00000                      0.00000
# 8                       0.00000                      0.00000
# 15                      0.00000                      0.00000
# 18                      0.00000                      0.00000
# 23                      2.43088                      2.40488
#
#     C0785_1F_1A_100k_1_profile  C0785_1F_1A_100k_2_profile  \
# 6                      0.00000                         0.0
# 8                      0.00000                         0.0
# 15                     0.00000                         0.0
# 18                     0.00000                         0.0
# 23                     0.33651                         0.0
#
#     C0785_1F_1A_100k_3_profile  C0785_1F_1A_100k_4_profile  \
# 6                      0.00000                     0.00000
# 8                      0.00000                     0.00000
# 15                     0.00000                     0.00000
# 18                     0.00000                     0.00000
# 23                     0.86882                     0.76952
#
#     C0785_1F_1A_10k_1_profile  C0785_1F_1A_10k_2_profile  \
# 6                         0.0                        0.0
# 8                         0.0                        0.0
# 15                        0.0                        0.0
# 18                        0.0                        0.0
# 23                        0.0                        0.0
#
#     C0785_1F_1A_10k_3_profile  C0785_1F_1A_10k_4_profile
# 6                         0.0                        0.0
# 8                         0.0                        0.0
# 15                        0.0                        0.0
# 18                        0.0                        0.0
# 23                        0.0                        0.0
#
# [5 rows x 361 columns]

# %%
subsample.to_csv('subsample_calculateshannon.csv')

# %%
# melt dataframes
subsample_melt = pd.melt(subsample, id_vars=["ID"], var_name = "sampleid", value_name = "abund")

# %%
subsample_melt.sample(30)
# Out:
#                                  ID                     sampleid    abund
# 46712                   Veillonella   C0524_3F_1A_100k_2_profile  0.00000
# 13621                 Anaerotruncus    C0043_7F_1A_10k_4_profile  0.00000
# 54545                   Collinsella    C0556_2F_1A_10k_4_profile  0.00000
# 40663                   Varibaculum    C0505_1F_1A_10k_3_profile  0.00000
# 62933               Parabacteroides   C0603_1F_1A_100k_4_profile  0.50586
# 53899  Peptostreptococcaceae_noname   C0556_2F_1A_100k_4_profile  0.00000
# 52018    Erysipelotrichaceae_noname    C0550_1F_1A_10k_2_profile  0.00000
# 20705                   Akkermansia  C0055_3F_1A_1000k_1_profile  0.00000
# 26907        Lachnospiraceae_noname    C0476_3F_1A_10k_2_profile  0.00000
# 30625                   Bacteroides   C0482_3F_1A_100k_2_profile  0.00000
# 43750                    Prevotella  C0517_1F_1A_1000k_3_profile  0.00000
# 58259        Lachnospiraceae_noname   C0595_1F_1A_100k_3_profile  0.00000
# 49408               Bifidobacterium    C0537_1F_1A_10k_1_profile  0.00000
# 1158                    Eggerthella   C0005_3F_1A_100k_3_profile  0.00000
# 43532                   Bacteroides  C0517_1F_1A_1000k_2_profile  0.00000
# 36432    Erysipelotrichaceae_noname    C0494_2F_1A_10k_4_profile  0.00000
# 44160                   Clostridium   C0517_1F_1A_100k_1_profile  0.00000
# 49394                   Haemophilus   C0537_1F_1A_100k_4_profile  0.00000
# 2488                    Eggerthella  C0016_3F_1A_1000k_2_profile  0.00000
# 36737                 Lactobacillus  C0498_1F_1A_1000k_2_profile  0.00000
# 30821                  Dysgonomonas   C0482_3F_1A_100k_3_profile  0.00000
# 33611                  Enterobacter    C0493_2F_1A_10k_1_profile  0.00000
# 67737                   Eubacterium    C0785_1F_1A_10k_1_profile  0.00000
# 7953                    Veillonella   C0029_6F_1A_100k_2_profile  0.00000
# 26974                   Haemophilus    C0476_3F_1A_10k_2_profile  0.00000
# 34987                   Bacteroides   C0494_2F_1A_100k_1_profile  0.00000
# 63279               Bifidobacterium    C0603_1F_1A_10k_2_profile  0.00000
# 9090                    Veillonella    C0029_6F_1A_10k_4_profile  0.00000
# 42883              Faecalibacterium    C0511_1F_1A_10k_2_profile  0.00000
# 56793                   Escherichia    C0557_1F_1A_10k_3_profile  0.00000

# %%
subsample_melt["replicate"] = subsample_melt['sampleid'].str.split("k_").str[-1]
subsample_melt["replicate"] = subsample_melt['replicate'].str.split("_profile").str[0]

# %%
subsample_melt["read_depth"] = subsample_melt['sampleid'].str.split("1A_").str[-1]

# %%
subsample_melt["read_depth"] = subsample_melt['read_depth'].str.split("k_").str[0]

# %%
subsample_melt.head(10)
# Out:
#                    ID                     sampleid    abund replicate  \
# 0  Methanobrevibacter  C0005_3F_1A_1000k_1_profile  0.00000         1
# 1  Methanobrevibacter  C0005_3F_1A_1000k_1_profile  0.00000         1
# 2         Actinomyces  C0005_3F_1A_1000k_1_profile  0.00000         1
# 3         Varibaculum  C0005_3F_1A_1000k_1_profile  0.00000         1
# 4     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.37811         1
# 5     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.00000         1
# 6     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.00000         1
# 7     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.00000         1
# 8     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.00000         1
# 9     Bifidobacterium  C0005_3F_1A_1000k_1_profile  0.00000         1
#
#   read_depth
# 0       1000
# 1       1000
# 2       1000
# 3       1000
# 4       1000
# 5       1000
# 6       1000
# 7       1000
# 8       1000
# 9       1000

# %%
subsample_melt.to_csv('subsample_cleaned.csv')
