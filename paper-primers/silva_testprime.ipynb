# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import csv
import janitor
import numpy as np

# %%
silva = pd.read_csv("arb-silva.de_testprime_taxlist_848715.csv", sep = ";")

# %%
silva
# Out:
#        job_name                                           taxonomy  coverage  \
# 0           NaN                      SILVA (only NR);Unclassified;       0.0
# 1           NaN                           SILVA (only NR);Archaea;      81.0
# 2           NaN           SILVA (only NR);Archaea;Aenigmarchaeota;       3.5
# 3           NaN  SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...       2.6
# 4           NaN  SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...       2.6
# 5           NaN  SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...       0.0
# 6           NaN  SILVA (only NR);Archaea;Aenigmarchaeota;Deep S...       3.9
# 7           NaN             SILVA (only NR);Archaea;Altiarchaeota;       7.5
# 8           NaN  SILVA (only NR);Archaea;Altiarchaeota;Altiarch...       7.5
# 9           NaN  SILVA (only NR);Archaea;Altiarchaeota;Altiarch...       7.5
# 10          NaN  SILVA (only NR);Archaea;Altiarchaeota;Altiarch...       7.5
# ...

# %%
silva["taxonomy"]
# Out:
# 0                            SILVA (only NR);Unclassified;
# 1                                 SILVA (only NR);Archaea;
# 2                 SILVA (only NR);Archaea;Aenigmarchaeota;
# 3        SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...
# 4        SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...
# 5        SILVA (only NR);Archaea;Aenigmarchaeota;Aenigm...
# 6        SILVA (only NR);Archaea;Aenigmarchaeota;Deep S...
# 7                   SILVA (only NR);Archaea;Altiarchaeota;
# 8        SILVA (only NR);Archaea;Altiarchaeota;Altiarch...
# 9        SILVA (only NR);Archaea;Altiarchaeota;Altiarch...
# 10       SILVA (only NR);Archaea;Altiarchaeota;Altiarch...
# 11       SILVA (only NR);Archaea;Altiarchaeota;Altiarch...
# 12                SILVA (only NR);Archaea;Asgardarchaeota;
# 13       SILVA (only NR);Archaea;Asgardarchaeota;Heimda...
# 14       SILVA (only NR);Archaea;Asgardarchaeota;Lokiar...
# 15       SILVA (only NR);Archaea;Asgardarchaeota;Odinar...
# ...

# %%
# remove everything before 7th semi-colon
